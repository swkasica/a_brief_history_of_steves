# %%
from vega import Vega, VegaLite
import time, datetime
from IPython.core.display import HTML
from IPython.display import IFrame, YouTubeVideo

slideWidth = 900
slideHeight = 600
toTimestamp = lambda s: time.mktime(datetime.datetime.strptime(s, "%m/%d/%Y").timetuple()) * 1e3
today = toTimestamp(datetime.datetime.now().strftime('%m/%d/%Y'))

# %%
# %%html
# <style>
#
# .steve-group img {
#     filter:grayscale(100%);
#     object-fit:cover;
#     position:absolute;border-radius:100%;
# }
#
#
# </style>
# Out:
# <style>
#
# .steve-group img {
#     filter:grayscale(100%);
#     object-fit:cover;
#     position:absolute;border-radius:100%;
# }
#
#
# </style>

# %% [markdown]
# # A Brief History of Steves
#
# Steve Kasica ([@swkasica](https://twitter.com/swkasica))
#
# Feb. 8, 2019
#
# https://github.com/swkasica/a_brief_history_of_steves
# <br>
# <audio controls>
#     <source src="media/stevesong.ogg" type="audio/ogg">
#     <source src="media/stevesong.mp3" type="audio/mpeg">
#     Your browser does not support the audio element.
# </audio>

# %% [markdown]
# * Thank UBC Computer Science Graduate Student Association
# * Forum to get something off my chest
# * Lately, need to reintroduce/introduce people to the Steve community
# * Because of three guys giving Steve a bad name

# %% [markdown]
# <h2>The Axis of St-evil</h2>
# <div class="steve-group" style="height:400px;overflow:hidden;">
#     <img alt="Steve Bannon" style="top:100px;left:125px;object-fit:cover;height:300px;width:300px;border-radius:100%" src="imgs/bannon_time.jpg">
#      <img style="filter:grayscale(100%);object-fit:cover; position:absolute;border-radius:100%;left:450px;top:100px;height:300px;width:300px" src="imgs/steven_miller.jpg">
#     <img style="filter:grayscale(100%);object-fit:cover; position:absolute; border-radius:100%;left:775px;top:100px;height:300px;width:300px;" src="imgs/steve_mnuchin.jpg">
# </div>

# %% [markdown]
# * Steve Bannon
# * Stephen Miller
# * Steve Mnuchin

# %% [markdown]
# ### The Axis of St-evil: Steve Mnuchin
#
# ![Steve Mnunchin Money](imgs/mnuchin_bond_villans.jpg)

# %% [markdown]
# * U.S. Secretary of the Treasury
# * Worth \$300 million
#     * Holding \$25
# * Photo w/ wife Louise Linton
# * Look like Bond Villans
# * Requested a military jet fly them to their European honeymoon.

# %% [markdown]
# ### The Axis of St-evil: Stephen Miller
# ![Stephen Miller](imgs/miller_creepy.jpg)

# %% [markdown]
# * Senior Advisor to the President and speech writer
# * Loudest voices in Trump Administration anti-immigration chorus
#     * High school told Latino students to speak only English
#     * Suppressed an internal govt. report, refugees => net positive effect on government revenues
# * Uncle wrote an essay "Stephen Miller Is an Immigration Hypocrite. I Know Because I'm His Uncle."
# * So creepy

# %% [markdown]
# ### The Axis of St-evil: Steve Bannon
# ![Steve Bannon Couch](imgs/bannon_shorts.jpg)

# %% [markdown]
# * Former White House Chief Strategist
# * "The King Maker"
# * Driving force behind
#     * U.S. out of Paris Agreement on climate change
#     * Travel ban
# * Called a ball hog by shipmates in Navy

# %% [markdown]
# ## Outline

# %% [markdown]
# * What is a Steve?
#     * Stephen vs. Steven

# %% [markdown]
# * Steves in Modern History
#     * Artists
#     * Scientists
#     * Athletes

# %% [markdown]
# * Steves in Popular Culture

# %% [markdown]
# * Need this time to show you we're not all like that
# * Three Parts

# %% [markdown]
# ## What is a Steve?

# %%
treeSchema = {
    "$schema": "https://vega.github.io/schema/vega/v4.json",
    "width": 700,
    "height": 400,
    "padding": 3,
    "signals": [
        {
            "name": "labels", 
            "value": True
        },
        {
            "name": "layout", 
            "value": "tidy"
        },
        {
            "name": "links", 
            "value": "orthogonal"
        }
    ],
    "data": [
        {
            "name": "tree",
            "values": [
                { "id": 2,  "name": "Στέφανος (Stéphanos)"},
                { "id": 3,  "name": "???", "parent": 2},
                { "id": 25, "name": "???", "parent": 2},                
                { "id": 4,  "name": "Steven",  "parent": 3},
                { "id": 5,  "name": "Stephen", "parent": 3},
                { "id": 6,  "name": "???", "parent": 2},
                { "id": 7,  "name": "Steve", "parent": 4 },
                { "id": 8,  "name": "Stevie", "parent": 4 },               
                { "id": 9,  "name": "Steve-o", "parent": 4 },
                { "id": 10, "name": "Steph", "parent": 24},
                { "id": 11, "name": "Stephe \"Steve\"", "parent": 5}, 
                { "id": 12, "name": "Stefan", "parent": 6},
                { "id": 13, "name": "Stefon", "parent": 6},                
                { "id": 14, "name": "Stevesy", "parent": 4},
                { "id": 15, "name": "Stephanie", "parent": 6},
                { "id": 26, "name": "Stefanie", "parent": 6},                
                { "id": 16, "name": "Stevesaurus Rex", "parent": 4},
                { "id": 17, "name": "Esteban", "parent": 23},
                { "id": 18, "name": "Steveson", "parent": 4},
                { "id": 19, "name": "Steffen", "parent": 6 },
                { "id": 20, "name": "Istifanous", "parent": 6},
                { "id": 21, "name": "スティーブン (Stiibun)", "parent": 23},
                { "id": 23, "name": "???", "parent": 2},
                { "id": 24, "name": "Stephan", "parent": 6},
                { "id": 26, "name": "Tapani", "parent": 25},
                { "id": 22, "name": "Степан (Stepan)", "parent": 25 },
                { "id": 27, "name": "Stefano", "parent": 6},
                { "id": 28, "name": "Steephan", "parent": 6},
            ],
            "transform": [
                {
                    "type": "stratify",
                    "key": "id",
                    "parentKey": "parent"
                },
                {
                    "type": "tree",
                    "method": { "signal": "layout" },
                    "size": [ 
                        { "signal": "height" }, 
                        { "signal": "width - 100" }
                    ],
                    "as": [ "y", "x", "depth", "children" ]
                }
            ]
        },
        {
            "name": "links",
            "source": "tree",
            "transform": [
                { "type": "treelinks" },
                { 
                    "type": "linkpath",
                    "orient": "horizontal",
                    "shape": { "signal": "links" }
                }
            ]
        }
    ],
    "scales": [
        {
            "name": "color",
            "type": "sequential",
            "range": {"scheme": "magma"},
            "domain": {"data": "tree", "field": "depth"},
            "zero": True
        }
    ],
    "marks": [
        {
            "type": "path",
            "from": {"data": "links"},
            "encode": {
                "update": {
                    "path": {"field": "path"},
                    "stroke": {"value": "#ccc"}
                }
            }
        },
        {
            "type": "symbol",
            "from": {"data": "tree"},
            "encode": {
                "enter": {
                "size": {"value": 100},
                "stroke": {"value": "#fff"}
            },
                "update": {
                    "x": {"field": "x"},
                    "y": {"field": "y"},
                    "fill": {"scale": "color", "field": "depth"}
            }
            }
        },
        {
            "type": "text",
            "from": {"data": "tree"},
            "encode": {
                "enter": {
                    "text": {"field": "name"},
                    "fontSize": { "value": 16 },
                    "baseline": {"value": "middle"}
                },
                "update": {
                    "x": {"field": "x"},
                    "y": {"field": "y"},
                    "dx": {"signal": "datum.children ? -7 : 7"},
                    "align": {"signal": "datum.children ? 'right' : 'left'"},
                    "opacity": {"signal": "labels ? 1 : 0"}
                }
            }
        }
    ]
};

# %% [markdown]
# <img alt="Tree named Steve" src="https://www.scholastic.com/content5/media/products/11/9780545245111_mres.jpg" style="height: 550px">
# <p><a href="https://www.scholastic.com">Source: Scholastic</a></p>

# %% [markdown]
# * Climb Tree of Steve
# * Zweibel's "Our Tree Named Steve"
#     * Blatent rip off of Shell Silverstein's "The Giving Tree"

# %%
Vega(treeSchema)

# %% [markdown]
# * Cross-cultural
#     * "スティーブン (Stiibun)" **Japan**
#     * "Istifanous" **Arabic**
#     * Stefan **German**
#     * "Степан (Stepan)" **Ukranian**
#     * Tapani **Finish**
#     * Sītífán **Mandarin Chinese**
#     * Stefano **Italian and Swahili**
#     * Steephan **India**
#
# * 4 groups: f, v, b, p sounds
# * Common v-sound ancestor

# %% [markdown]
# ### Stephen vs. Steven
#
# Stephen > Steven

# %% [markdown]
# ![Google Book Ngram](imgs/ngram.png)

# %% [markdown]
# * Can't be objective
# * Unigram => probability of Stephen vs. Steven
# * English Literature
# * Steven after 1960
# * V-vs-PH war is real.
#     * Live it my whole life

# %% [markdown]
# <h3>Stephen vs. Steven</h3>
# <img alt="Steve Kindergarten" height="300px" src="imgs/kindergarten.jpg">

# %% [markdown]
# * Emotional scars
# * Kindergarten (5 years old)
# * Accused my mom of spelling my name wrong
# * Can hear "ph"/"v"

# %%
baby_names = {
    "$schema": "https://vega.github.io/schema/vega-lite/v3.json",
    "title": "Baby Name Popularity in The U.S.",
    "data": {"url": "data/ss_baby_names.csv"},
    "width": 750,
    "height": 500,
    "mark": "line",
    "encoding": {
        "x": {"field": "year", "type": "temporal"},
        "y": {"field": "rank", "type": "quantitative", "sort": "descending"},
        "color": {"field": "name", "type": "nominal"},
    }
}

# %%
VegaLite(baby_names)

# %% [markdown]
# * U.S. Social Security Administration records baby names
# * Steven surpasses Stephen ~ 1950
# * In decline after decades in top 100
#
#
# * If you have children, please consider making them a Steve
# * They'll be in good company

# %% [markdown]
# > "If you forget an old white guy's name, you have a descent chance if you just throw out a Steve." <br> -- Seth Meyers, *Late Night with Seth Meyers*, Jan. 6, 2019

# %% [markdown]
# * True if their legal name is Steve
# * But not if their legal name is Steven or Stephen
# * Screw you Seth Meyers, check your facts.

# %% [markdown]
# ## Steves in Modern History

# %%
steves = [
        {
          "label": "Stephen Miller",
          "born": toTimestamp('8/23/1985'),
          "died": today,
          "enter": toTimestamp('11/1/2016'),
          "leave": today
        },{
          "label": "Stephen Bannon",
          "born": toTimestamp('11/27/1953'),
          "died": today,
          "enter": toTimestamp('8/1/2016'),
          "leave": today
        },{
          "label": "Steven Mnuchin",
          "born": toTimestamp('12/21/1962'),
          "died": today,
           "enter": toTimestamp('11/1/2016'),
           "leave": today,
        },{
          "label": "Stephen Hawking",
          "born": toTimestamp('1/8/1942'),
          "died": toTimestamp('3/14/2018'),
           "enter": toTimestamp('1/1/1970'),
           "leave": toTimestamp('3/14/2018')
        },{
          "label": "Stephen Colbert",
          "born": toTimestamp('5/13/1964'),
          "died": today,
           "enter": toTimestamp('1/1/1984'),
           "leave": today
        },{
          "label": "Stevie Nicks",
          "born": toTimestamp("5/26/1948"),
          "died": today,
          "enter": toTimestamp('1/1/1966'),  # start of active years
          "leave": today
        },{
          "label": "Steve Martin",  # Stephen
          "born": toTimestamp("8/14/1945"),
          "died": today,
          "enter": toTimestamp("1/1/1967"),
          "leave": today,
        },{
            "label": "Steve Jobs",  # Steven
            "born": toTimestamp("2/24/1955"),
            "died": toTimestamp("10/5/2011"),
            "enter": toTimestamp("1/1/1976"),
            "leave": toTimestamp("10/5/2011")            
        },{
            "label": "Steph Curry",  # Stephen
            "born": toTimestamp("3/14/1988"),
            "died": today,
            "enter": toTimestamp("1/1/2009"),
            "leave": today
        },{
            "label": "Steve Harvey",
            "born": toTimestamp("1/17/1957"),
            "died": today,
            "enter": toTimestamp("1/1/1985"),
            "leave": today,
        },{
            "label": "Steve Irwin",
            "born": toTimestamp("2/22/1962"),
            "died": toTimestamp("9/4/2006"),
            "enter": toTimestamp("1/1/1991"),
            "leave": toTimestamp("9/4/2006"),
        },{
            "label": "Steve Wozniak",
            "born": toTimestamp("8/11/1950"),
            "died": today,
            "enter": toTimestamp("1/1/1976"),
            "leave": today,                        
        },{
            "label": "Steve Burns",  # Blue's Clues,
            "born": toTimestamp("10/9/1973"),
            "died": today,
            "enter": toTimestamp("9/8/1996"),
            "leave": toTimestamp("1/1/2007")
        },{
            "label": "Steve McQueen",
            "born": toTimestamp("3/24/1930"),
            "died": toTimestamp("11/7/1980"),
            "enter": toTimestamp("1/1/1958"),
            "leave": toTimestamp("11/7/1980")
        },{
            "label": "Steve Carell",
            "born": toTimestamp("8/16/1962"),
            "died": today,
            "enter": toTimestamp("1/1/1999"),
            "leave": today
        },{
            "label": "Steve Wynn",
            "born": toTimestamp("1/27/1942"),
            "died": today,
            "enter": toTimestamp("1/1/1967"),
            "leave": today,
        },{
            "label": "Steve Prefontaine",
            "born": toTimestamp("1/25/1951"),
            "died": toTimestamp("5/30/1975"),
            "enter": toTimestamp("1/1/1970"),
            "leave": toTimestamp("5/30/1975")
        },{
            "label": "Steve Kroft",
            "born": toTimestamp("8/22/1945"),
            "died": today,
            "enter": toTimestamp("1/1/1980"),
            "leave": today
        },{
            "label": "Steve Forbes",  # Malcom Steveson Forbes
            "born": toTimestamp("7/18/1947"),
            "died": today,
            "enter": toTimestamp("1/1/1973"),
            "leave": today
        },{
            "label": "Steve Nash",
            "born": toTimestamp("2/7/1974"),
            "died": today,
            "enter": toTimestamp("1/1/1996"),
            "leave": toTimestamp("1/1/2015"),
        },{
            "label": "Stephen Baldwin",
            "born": toTimestamp("5/12/1966"),
            "died": today,
            "enter": toTimestamp("1/1/1986"),
            "leave": today,
        },{
            "label": "Stephen Baldwin",
            "born": toTimestamp("5/12/1966"),
            "died": today,
            "enter": toTimestamp("1/1/1986"),
            "leave": today,            
        },{
            "label": "Stephen Aoki",
            "born": toTimestamp("11/3/1977"),
            "died": today,
            "enter": toTimestamp("1/1/1996"),
            "leave": today,                        
        },{
            "label": "Stevie Wonder",
            "born": toTimestamp("5/13/1950"),
            "died": today,
            "enter": toTimestamp("1/1/1961"),
            "leave": today,                                    
        }
      ]

# %%
timeline = {
  "$schema": "https://vega.github.io/schema/vega/v4.json",
  "width": slideWidth,
  "height": 400,
  "padding": 5,

  "data": [
    {
      "name": "people",
      "values": sorted(steves, key = lambda x: x['born']),
    },{
      "name": "events",
      "format": {"type":"json", "parse":{"when":"date"}},
      "values": [
         { "name":"Trump Administration", "when":"1/20/2016" },
         { "name":"September 11 attacks", "when":"9/11/2001" },
         { "name":"Fall of Berlin Wall",    "when":"11/9/1989" },
         { "name":"Woodstock", "when":"8/15/1969" }
      ],
    }
  ],  # end data

  "scales": [
    {
      "name": "yscale",
      "type": "band",
      "range": [0, {"signal": "height"}],
      "domain": {"data": "people", "field": "label"}
    },
    {
      "name": "xscale",
      "type": "time",
      "interval": "year", 
      "step": 10,
      "range": "width",
      "round": True,
      "domain": {"data": "people", "fields": ["born", "died"]}
    }
  ],

  "axes": [
    {"orient": "bottom", "scale": "xscale", "format": "%Y"}
  ],

  "marks": [
    {
      "type": "text",
      "from": {"data": "events"},
      "encode": {
        "enter": {
          "x": {"scale": "xscale", "field": "when"},
          "y": {"value": -10},
          "angle": {"value": -25},
          "fill": {"value": "#000"},
          "text": {"field": "name"},
          "fontSize": {"value": 10}
        }
      }
    },
    {
      "type": "rect",
      "from": {"data": "events"},
      "encode": {
        "enter": {
          "x": {"scale": "xscale", "field": "when"},
          "y": {"value": -8},
          "width": {"value": 1},
          "height": {"field": {"group": "height"}, "offset": 8},
          "fill": {"value": "#888"}
        }
      }
    },
    {
      "type": "text",
      "from": {"data": "people"},
      "encode": {
        "enter": {
          "x": {"scale": "xscale", "field": "born"},
          "y": {"scale": "yscale", "field": "label", "offset": -3},
          "fill": {"value": "#000"},
          "text": {"field": "label"},
          "fontSize": {"value": 10}
        }
      }
    },
    {
      "type": "rect",
      "from": {"data": "people"},
      "encode": {
        "enter": {
          "x": {"scale": "xscale", "field": "born"},
          "x2": {"scale": "xscale", "field": "died"},
          "y": {"scale": "yscale", "field": "label"},
          "height": {"value": 2},
          "fill": {"value": "#557"}
        }
      }
    },
    {
      "type": "rect",
      "from": {"data": "people"},
      "encode": {
        "enter": {
          "x": {"scale": "xscale", "field": "enter"},
          "x2": {"scale": "xscale", "field": "leave"},
          "y": {"scale": "yscale", "field": "label", "offset":-1},
          "height": {"value": 4},
          "fill": {"value": "#e44"}
        }
      }
    }  # type: rect
  ]
}

# %%
Vega(timeline)

# %% [markdown]
# * Wynn: Businessman, basically made Las Vegas what is it today
# * Burns: Blues Clues

# %% [markdown]
# <h2>Steves are Artists</h2>
#
# <div class="steve-group" style="height:450px">
#     <img style="filter:grayscale(100%);object-fit:cover;position:absolute;border-radius:100%;top:100px;left:400px;height:300px;width:300px;" src="imgs/nicks_1977.jpg" alt="stevie nicks">
#      <img style="filter:grayscale(100%);object-fit:cover;position:absolute;border-radius:100%;right:0px;top:100px;height:200px;width:200px" src="imgs/wonder_1967.jpg" alt="stevie wonder">
#     <img style="filter:grayscale(100%);object-fit:cover;position:absolute;border-radius:100%;left: 240px;top: 275px;height:250px;width:250px;" src="imgs/colbert.jpg" alt="stephen colbert">
#     <img style="filter:grayscale(100%);object-fit:cover;position:absolute;border-radius:100%;left: 113px;top: 220px;height:200px;width:200px;" src="imgs/martin_2015.jpg" alt="Steve Martin">
#     <img style="filter:grayscale(100%);object-fit:cover;position:absolute;border-radius:100%;top: 289px;right: 234px;height: 200px;width: 200px;x;" src="imgs/steve_aoki.jpg" alt="Steve Aoki">
#     <img style="filter:grayscale(100%);object-fit:cover;position:absolute;border-radius:100%;bottom: 15px;right: 68px;height:150px;width:150px;" src="imgs/spielberg.jpg" alt="Steven Speilberg"><img style="filter:grayscale(100%);object-fit:cover;position:absolute;border-radius:100%;top: 101px;left: 240px;height:200px;width:200px;" src="imgs/esteban.jpg" alt="Esteban">
#     <img style="filter:grayscale(100%);object-fit:cover;position:absolute;border-radius:100%;top:50px;right:150px;height:200px;width:200px;" src="imgs/king.jpg" alt="Stephen King">
# </div>

# %% [markdown]
# * **Steve Martin**
#     * SNL and Bluegrass half of Famer
# * **Esteban**
# * **Stephen Colbert**
#     * First Stephen Late Night host
# * **Stevie Nicks**
#     * Steves aren't just dudes
# * **Steve Aoki (Eh-Oh-key)**
#     * EDM artist
#     * Known for known Kid Cudi remixes
# * **Stephen King**
#     * National Book Award Winner
# * **Stevie Wonder**
#     * Singer songwriter
# * **Stephen Speilberg**
#     * Director

# %% [markdown]
# ### Stevie Nicks
# ![Nicks in 2017](imgs/nicks_2017.jpg)
# * Born May 26, 1948
# * One of the greatest songwriters of all time
# * Vocalists in Fleetwood Mac

# %% [markdown]
# * American singer and songwriter, best known as vocalist with Fleetwood Mac
# * Inducted in Rock and Roll Hall of Fame (Fleetwood Mac) 1998 and will be inducted as a solo artist in 2019.
# * As a solo artist, she's received eight grammy nominations but zero awards.
#     * Stevie Wonder has 25 grammys

# %% [markdown]
# ## Steves are Curious
#
# <div class="steve-group" style="height:450px">
#      <img style="filter:grayscale(100%);object-fit:cover;position:absolute;border-radius:100%;right:100px;top: 59px;height:200px;width:200px;" src="imgs/gould.jpg" alt="Stephen Gould">
#      <img style="filter:grayscale(100%);object-fit:cover;position:absolute;border-radius:100%;right:350px;top: 100px;height:200px;width:200px;" src="imgs/ritchie.jpg" alt="Steve Ritchie">
#     <img style="filter:grayscale(100%);object-fit:cover;position:absolute;border-radius:100%;left: 180px;top: 200px;height:250px;width:250px;" src="imgs/kroft.jpg" alt="Steve Kroft">
#     <img style="filter:grayscale(100%);object-fit:cover;position:absolute;border-radius:100%;bottom: 11px;right:300px;height:200px;width:200px;" src="imgs/kwolek.jpg" alt="Stephanie Kwolek">
#     <img style="filter:grayscale(100%);object-fit:cover;position:absolute;border-radius:100%;top:100px;left:250px;height: 200px;width: 200px;" src="imgs/hawking.jpg" alt="Stephen Hawking">
# </div>

# %% [markdown]
# * Scientists and journalists and engineers (want to know how things work)
# * **Stephen Hawking**
#     * Theoretical physists
# * **Stephen Jay Gould**
#     * Evolutionary biologist
#     * Project Steve
# * **Steve Kroft**
#     * 60 Minutes correspondent
# * **Steve Ritchie**
#     * Holds the record for best-selling pinball designer in history
#     * Called "The Master of Flow"
# * **Stephanie Kwolek "Qua-lick"**
#     * Chemist
#     * Created the first family of synthetic fibers, exceptional strength and stiffness
#         * best known is Kevlar - used in 200 applications

# %% [markdown]
# ### Stephen Hawking: Theoretical Physicist
#
# ![Hawking Simpsons](imgs/hawking.gif)
#
# * Jan. 8, 1942 - March 14, 2018
# * Diagnosed with ALS at age 21
# * Pop Culture Icon

# %% [markdown]
# ### Stephen Hawking Notes
#
# * Theoretical physicist: explaining the origins of the universe and black holes
# * Diagnosed with amyotropic lateral sclerosis (ALS, or Lou Gehrig's disease) at age 21
#     * Doctors gave him 2.5 years to live, he did 52.5.
# * Wrote or co-authored 15 books including
#     * A Brief History of Time: four years atop the London Sunday Times' best-sellers list.
# * Ashes are interred at Westminster Abbey alongside Newton and Charles Darwin.

# %% [markdown]
# ### Stephen Jay Gould: Evolutionary Biologist
#
# ![Stephen Jay Gould](imgs/gould.jpg)
# * September 10, 1941, - May 20, 2002
# * Authored 300 popular essays in <em>Natural History</em> magazine
# * Project Steve

# %% [markdown]
# ### Stephen Jay Gould Notes
#
# * Theory of punctuated equilibrium
#     * long stable periods, infrequent swift periods of branching speciation.
# * Inspiration for Project Steve
#     * 2003
#     * Anti-evolution petittion, Discovery Institute
#     * National Center for Science Education, pro-evolution counterpart,
#     * \> 1,400 signatures

# %% [markdown]
# ## Steves are athletic
#
# <div class="steve-group" style="height: 450px">
#     <img alt="Steph Curry" style="filter:grayscale(100%);object-fit:cover;position:absolute;border-radius:100%;top: 100px;left: 382px;height: 300px;width: 300px;" src="imgs/curry.jpg">
#      <img alt="Stephanie Venier" style="filter:grayscale(100%);object-fit:cover;position:absolute;border-radius:100%;right: 75px;top: 50px;height: 200px;width: 200px;" src="imgs/venier.jpg">
#     <img alt="Steve Nash" style="filter:grayscale(100%);object-fit:cover;position:absolute;border-radius:100%;left: 249px;bottom: 12px;height: 250px;width: 250px;" src="imgs/nash.jpg">
#     <img style="filter:grayscale(100%);object-fit:cover;position:absolute;border-radius:100%;left: 119px;top: 107px;width: 200px;" src="imgs/prefontaine.jpg" alt="Steve Prefontaine">
#     <img alt="Steve Young" style="filter:grayscale(100%);object-fit:cover;position:absolute;border-radius:100%;bottom: 60px;right: 100px;height: 200px;width: 200px;object-position:0 0 !important;" src="imgs/young.jpg">
# </div>

# %% [markdown]
# * **Steve Prefontaine**
#     * Running icon and 1972 Olympian.
# * **Steve Nash**
#     * Macleans called one of "Canada's greatest athletes of all time"
#     * Pro basketballer with 18 seasons in the NBA
# * **Steph Curry**
#     * Golden State
#     * 6 x NBA All-Star, 2 x MVP, 3 x Champs
# * **Steve Young (Jon Steven Young)**
#     * 3 x Super Bowl Champion
#     * 49ers (1987-1999)
#     * San Francisco 49ers & BYU Retired No. 8
# * **Stephanie Venier**
#     * Austrian World Cup alpine ski racer
#     * Silver medal in downhill 2017 FIS World Championships
#         * Hirscher's not the only good Austrian ski racer, Michael!

# %% [markdown]
# ### Steph Curry
# ![Steph Curry](imgs/curry.jpg)
#
# * Wardell Stephen Curry II
# * Born March 14, 1988
# * Plays for Golden State Warriors

# %% [markdown]
# * First player since Michael Jordan to score 118 points in his team's first three games.
# * Named the NBA MVP twice and won 3 NBA Championships with the Golden State Warriors.
#     * 1st MVP (2015-2016) by a unamious vote.
# * Charity work: combat malaria
#     * Donate three mosquito nets for every three-pointer.

# %% [markdown]
# ## One Steve is good

# %% [markdown]
# ## But Steve + Steve =

# %% [markdown]
# ![Woz and Jobs](https://alumni.berkeley.edu/sites/default/files/image/wozniakapple.jpg)

# %% [markdown]
# * You get Apple
# * When you get multiple Steves together, there's no limit to what we can achieve.

# %% [markdown]
# ## In popular culture

# %%
google_trends = {
    "$schema": "https://vega.github.io/schema/vega-lite/v3.json",
    "title": "Interest in \"Steve\" Over Time",
    "data": {"url": "data/steve_google_trends.csv"},
    "width": 600,
    "height": 400,
    "mark": "line",
    "encoding": {
        "x": {"field": "Month", "type": "temporal"},
        "y": {"field": "Interest", "type": "quantitative"}
    }
}

# %%
VegaLite(google_trends)

# %% [markdown]
# * Interest relative to highest interest at any given time
# * September 2006: Steve Irwin Died
# * October 2011: Steve Jobs Died

# %% [markdown]
# ### Steves as Internet Memes
#
# ![Scumbag Steve Meme](http://img405.imageshack.us/img405/9660/scumbagstevephotou15.jpg)

# %% [markdown]
# * "an opportunistic and freeloading juvenile who wreak havoc in various social situations." -- KnowYourMeme
# * Started around 11
# * The guy's name is Blake Boston!

# %% [markdown]
# <h3>Steves as Heros</h3>
# <img src="imgs/rogers.jpg" style="width:45%;margin-right:10%;float:left;border-radius:100%;">
# <img src="imgs/harrington.jpg" style="width:45%;float:left;border-radius:100%">

# %% [markdown]
# * Steve Rogers (Captin America)
#     * Top 100 Comic Book Heroes of All Time - IGN
# * Steve Harrington
#     * Only character to go toe-to-toe with the Demigorgon and live

# %% [markdown]
# <h3>In Song Lyrics</h3>
#
# 1. **"Hey Stephen" Taylor Swift**
# 2. "St. Stephen" Greatful Dead
# 3. "Steven's Last Night in Town"
# 4. **"Stephen" Ke\$sha**
# 5. "Steven" Alice Cooper
# 6. "Steve McQueen" Sherly Crow
# 7. "Steve McQueen" Drive-By Truckers
# 8. "Stephen" Gene Loves Jezebel
# 9. "Steve Lacy" Harry Connick, Jr.
# 10. "Steve Biko (Stir It Up)" A Tribe Called Quest
# 11. "Steven Seagal" Droids Attack
#
# ...

# %% [markdown]
# ### Steve (atmospheric phenomenon)
#
# ![Steve atmospheric phenomenon](imgs/steve_atmosphere.jpg)

# %% [markdown]
# * Discovered in 2016 by FB Alberta Aurora Chasers
# * 25 km wide ribbon of hot plasma, much closer to equator than an aurora.
# * One suggested the name Steve from *Over the Hedge*
# * NASA has renamed it "Strong Thermal Emission Velocity Enhancement" STEVE

# %% [markdown]
# # A Brief History of Steves

# %%
IFrame('https://www.youtube.com/embed/nEea_wNQUM8?controls=0&amp;start=229', width=600, height=400)
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="https://www.youtube.com/embed/nEea_wNQUM8?controls=0&amp;start=229"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# * Steves Not Greedy, xenophobic, slobs
# * We're artists, scientists, journalists, athletes with a proud history

# %% [markdown]
# # Questions?

# %% [markdown]
# Such as:
#
# * Can I change my name to Steve?
# * When do I call someone ˈstiːvən vs. ˈʃtɛfan?
# * What about Stephen Feinberg?
# * What about Kevin McCarthy?

# %% [markdown]
# ## Supplementary Materials

# %% [markdown]
# ### Colbert on Stephen vs. Steve

# %%
YouTubeVideo('JX3sD7FpsGM', width=600, height=400)

# %% [markdown]
# ### Is Kevin McCarthy an honorary Steve?

# %%
YouTubeVideo('nFyOd1kNVQA', start=436)

# %% [markdown]
# * Kevin McCarthy (R-Calif.) House Minority Leader
